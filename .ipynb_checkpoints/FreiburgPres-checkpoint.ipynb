# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
from rasterio.mask import mask
from rasterio.plot import show
from matplotlib import pyplot as plt
from matplotlib.patches import Rectangle
import textwrap
from matplotlib.text import Text

import Plot_Tricks as pt
import Maps as Maps
import ResultsPlots as RS
from shapely.geometry import box 
import matplotlib.image as mpimg

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import importlib
importlib.reload(RS)
importlib.reload(pt)
importlib.reload(Maps)
% matplotlib inline


TitleFont = 90
TitleSpace = 90
TitlePad = 10
AuthorPad = 35
InfoPad = 30

HeaderFont = 60
HeadSpace = 25
pad = 10
HeadPad = HeadSpace + pad
TextFont = 34
SubTextfont = 30
SmallTextfont = 26

Major_Label_Font = 25
Minor_Label_Font = 20


HeaderPad = 35
pane_y_pad = 6

Background_Color = (.9,.9,.9)
Master_Background_Color = (.97,.97,.97)
dpi = 300

% matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %%
importlib.reload(RS)

DataPath = 'C:/FishIsland_2017/FilteredData2018-04-09.csv'
FilledPath_ch4 = 'C:/FishIsland_2017/GapFilledfch4.csv'
SummaryPath_ch4 = 'C:/FishIsland_2017/GapFillingSummaryfch4.csv'
FilledPath_co2 = 'C:/FishIsland_2017/GapFilledfco2.csv'
SummaryPath_co2 = 'C:/FishIsland_2017/GapFillingSummaryfco2.csv'


results = RS.Results(DataPath,FilledPath_ch4,SummaryPath_ch4,FilledPath_co2,SummaryPath_co2,Major_Label_Font,Minor_Label_Font)

def mm_in(Size):
    Size=(Size[0]*0.0393701,Size[1]*0.0393701)
    return(Size)

fig,ax = plt.subplots(1,1,figsize=mm_in((550,200)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)

results.Climate(ax)
plt.savefig('C:\\Users\\wesle\\FreiburgPres/Climatology.png',dpi = 400)


fig,ax = plt.subplots(1,1,figsize=mm_in((550,170)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)


x1 = 504665.0
y1 = 7695865.0
x2 = x1+50
y2 = y1+50
bounds = [x1,y1,x2,y2]

xs,ys = 0.23,.92
x1,y1 = 0.01,0.01
x2,y2 = 0.26,0.01
x3,y3 = 0.51,0.01
x4,y4 = 0.76,0.01
pos=xs,ys,x1,y1,x2,y2,x3,y3,x4,y4

PC = Maps.Phenology_Change(ax,Major_Label_Font,Minor_Label_Font,bounds,pos)
Units = 10
Posx = 32
Posy = 2
Posx2 = 37
Posy2 = 7
size = 12
PC.Scale(PC.ax4,Units,Posx,Posy,Posx2,Posy2,size)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.savefig('C:\\Users\\wesle\\FreiburgPres/Phenology.png',dpi = 400)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
importlib.reload(RS)

results = RS.Results(DataPath,FilledPath_ch4,SummaryPath_ch4,FilledPath_co2,SummaryPath_co2,Major_Label_Font,Minor_Label_Font)



fig,ax = plt.subplots(1,1,figsize=mm_in((600,400)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)
rect = rec_pos(600,400,0,0,600,400)
ax1 = pt.add_subplot_axes(ax,rect)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)
results.GPP_ER(ax1)
plt.savefig("C:\\Users\\wesle\\FreiburgPres/ResponseFuncs.png",dpi = 400)




fig,ax = plt.subplots(1,1,figsize=mm_in((600,400)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)
results.BestML(ax)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# plt.tight_layout()
plt.savefig("C:\\Users\\wesle\\FreiburgPres/ML.png",dpi = 400)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# [ 0.055  0.555] [ 0.06  0.56]
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# [ 0.075  0.405  0.735] [ 0.075  0.575]

# %%
print(Minor_Label_Font)

importlib.reload(RS)
results = RS.Results(DataPath,FilledPath_ch4,SummaryPath_ch4,FilledPath_co2,SummaryPath_co2,Major_Label_Font,Minor_Label_Font)


def rec_pos(w1,h1,x1,y1,w2,h2):
    rect = [x1/w1,y1/h1,w2/w1,h2/h1]
    return(rect)



fig,ax = plt.subplots(1,1,figsize=mm_in((500,400)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

rect = rec_pos(500,400,0,0,500,400)


ax1 = pt.add_subplot_axes(ax,rect)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)
# results.CH4(ax1,fig)
results.Factors(ax1)
plt.savefig("C:\\Users\\wesle\\FreiburgPres/ML_CO2.png",dpi = 400)


fig,ax = plt.subplots(1,1,figsize=mm_in((500,400)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

rect = rec_pos(500,400,0,0,500,400)


ax1 = pt.add_subplot_axes(ax,rect)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)
# results.CH4(ax1,fig)
results.Factors2(ax1)
plt.savefig("C:\\Users\\wesle\\FreiburgPres/ML_CH4.png",dpi = 400)
# Out:
# 20
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# [ 0.075  0.575] [ 0.05  0.55]
# 0.704697809632 0.729691566384 0.761480997422 0.801934820138 0.822867705987
# [ 0.075  0.575] [ 0.05  0.55]
# 0.230745335461 0.286466487008 0.349949311515 0.403239181052 0.476231329561

# %%
importlib.reload(RS)
results = RS.Results(DataPath,FilledPath_ch4,SummaryPath_ch4,FilledPath_co2,SummaryPath_co2,Major_Label_Font,Minor_Label_Font)


Cbal_W,Cbal_H=600,370

fig,ax = plt.subplots(1,1,figsize=mm_in((Cbal_W,Cbal_H)))
fig.subplots_adjust(left=0, bottom=0, right=1, top=1)

rect = rec_pos(Cbal_W,Cbal_H,0,0,Cbal_W,Cbal_H)
ax1 = pt.add_subplot_axes(ax,rect)
results.C_Balance(ax1)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.savefig("C:\\Users\\wesle\\FreiburgPres/CBal.png",dpi = 400)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# -0.357033373758
# 0.21147264167
# 0.284253007714
